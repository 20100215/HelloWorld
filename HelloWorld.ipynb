# %% [markdown]
# ## **CS 4103 - Intelligent Systems**
# ### Assignment 1 - Exploring Jupyter Notebook and Visualizing Data
# ### Submitted by: Wayne Matthew A. Dayata (20100215)

# %%
## Print code execution time
from datetime import datetime, timedelta

now = datetime.now()
now += timedelta(hours=8) #UTC+8
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print("Date and time of code execution: ", dt_string)
# Out:
# Date and time of code execution:  24/08/2023 21:44:40

# %% [markdown]
# ## Import necessary modules

# %%
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np
import pandas as pd
import math
import datetime
# %matplotlib inline
print('Modules loaded')
# Out:
# Modules loaded

# %% [markdown]
# ## Load and explore CSV file (dataset) content

# %%
# read the csv file
df = pd.read_csv("/content/camera_dataset.csv")
df
# Out:
#                        Model  Release date  Max resolution  Low resolution  \
# 0           Agfa ePhoto 1280          1997          1024.0           640.0
# 1           Agfa ePhoto 1680          1998          1280.0           640.0
# 2           Agfa ePhoto CL18          2000           640.0             0.0
# 3           Agfa ePhoto CL30          1999          1152.0           640.0
# 4     Agfa ePhoto CL30 Clik!          1999          1152.0           640.0
# ...                      ...           ...             ...             ...
# 1033         Toshiba PDR-M65          2001          2048.0          1024.0
# 1034         Toshiba PDR-M70          2000          2048.0          1024.0
# 1035         Toshiba PDR-M71          2001          2048.0          1024.0
# 1036         Toshiba PDR-M81          2001          2400.0          1200.0
# 1037         Toshiba PDR-T10          2002          1600.0           800.0
#
# ...

# %%
df.dtypes
# Out:
# Model                       object
# Release date                 int64
# Max resolution             float64
# Low resolution             float64
# Effective pixels           float64
# Zoom wide (W)              float64
# Zoom tele (T)              float64
# Normal focus range         float64
# Macro focus range          float64
# Storage included           float64
# Weight (inc. batteries)    float64
# Dimensions                 float64
# Price                      float64
# dtype: object

# %%
df.describe()
# Out:
#        Release date  Max resolution  Low resolution  Effective pixels  \
# count   1038.000000     1038.000000     1038.000000       1038.000000
# mean    2003.590559     2474.672447     1773.936416          4.596339
# std        2.724755      759.513608      830.897955          2.844044
# min     1994.000000        0.000000        0.000000          0.000000
# 25%     2002.000000     2048.000000     1120.000000          3.000000
# 50%     2004.000000     2560.000000     2048.000000          4.000000
# 75%     2006.000000     3072.000000     2560.000000          7.000000
# max     2007.000000     5616.000000     4992.000000         21.000000
#
#        Zoom wide (W)  Zoom tele (T)  Normal focus range  Macro focus range  \
# count    1038.000000    1038.000000         1038.000000        1037.000000
# mean       32.963391     121.525048           44.145472           7.787850
# std        10.333149      93.455422           24.141959           8.100081
# ...

# %% [markdown]
# ## Visualizing the data

# %%
# Draw a pairplot using seaborn scatterplots
g = sn.pairplot(df)

# %% [markdown]
# ## Testing Correlation

# %%
# Printing correlation info
print(df.corr())

# plotting correlation heatmap
dataplot = sn.heatmap(df.corr(), annot=True)

# displaying heatmap
plt.show()
# Out:
# <ipython-input-9-afc37b170671>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(df.corr())
# <ipython-input-9-afc37b170671>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataplot = sn.heatmap(df.corr(), annot=True)
#                          Release date  Max resolution  Low resolution  \
# Release date                 1.000000        0.788682        0.745426
# Max resolution               0.788682        1.000000        0.838381
# Low resolution               0.745426        0.838381        1.000000
# Effective pixels             0.790742        0.953949        0.815669
# ...

# %% [markdown]
# **Dataset:**
# 1000 Cameras Dataset - https://www.kaggle.com/datasets/crawford/1000-cameras-dataset?resource=download
#
# **References:**
#
# 1. How To Read CSV Files In a Jupyter Notebook Online - https://saturncloud.io/blog/how-to-read-csv-files-in-a-jupyter-notebook-online/
# 2. How to Quickly Visualize Data Using Python and Jupyter Notebooks - https://www.beeboxdesigns.com/codetalk/how-to-quickly-visualize-data-using-python-and-jupyter-notebooks/
# 3. How to create a seaborn correlation heatmap in Python? - https://www.geeksforgeeks.org/how-to-create-a-seaborn-correlation-heatmap-in-python/
